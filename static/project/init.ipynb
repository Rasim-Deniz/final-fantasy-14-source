# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (1.2.5)
# Collecting networkx
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Collecting fa2
#   Downloading fa2-0.3.5.tar.gz (435 kB)
# Collecting igraph
#   Downloading igraph-0.9.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.2 MB)
# Requirement already satisfied: seaborn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 6)) (0.11.2)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 7)) (3.4.3)
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
# Collecting powerlaw
#   Downloading powerlaw-1.5-py3-none-any.whl (24 kB)
# Requirement already satisfied: nltk in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 10)) (3.6.5)
# Collecting community
#   Downloading community-1.0.0b1.tar.gz (2.2 kB)
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Collecting python-louvain
#   Downloading python-louvain-0.15.tar.gz (204 kB)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fa2->-r ./requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fa2->-r ./requirements.txt (line 4)) (4.62.3)
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 7)) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: mpmath in /shared-libs/python3.7/py/lib/python3.7/site-packages (from powerlaw->-r ./requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 10)) (2021.11.10)
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->-r ./requirements.txt (line 10)) (8.0.3)
# Collecting Flask
#   Downloading Flask-2.0.2-py3-none-any.whl (95 kB)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from community->-r ./requirements.txt (line 11)) (2.26.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r ./requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from click->nltk->-r ./requirements.txt (line 10)) (4.8.2)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: Jinja2>=3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from Flask->community->-r ./requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from Flask->community->-r ./requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->community->-r ./requirements.txt (line 11)) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->community->-r ./requirements.txt (line 11)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->community->-r ./requirements.txt (line 11)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->community->-r ./requirements.txt (line 11)) (3.3)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->click->nltk->-r ./requirements.txt (line 10)) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->click->nltk->-r ./requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from Jinja2>=3.0->Flask->community->-r ./requirements.txt (line 11)) (2.0.1)
# Building wheels for collected packages: fa2, community, python-louvain
#   Building wheel for fa2 (setup.py): started
#   Building wheel for fa2 (setup.py): finished with status 'done'
#   Created wheel for fa2: filename=fa2-0.3.5-cp37-cp37m-linux_x86_64.whl size=151468 sha256=02d4a38617207d4b16dda6b4481a7dbb01497581e45c89bc784a0cd31f361ffb
#   Stored in directory: /root/.cache/pip/wheels/d3/b5/0a/df14cac170d872be0dd0300309b7463b5e52d936c3edce7963
#   Building wheel for community (setup.py): started
#   Building wheel for community (setup.py): finished with status 'done'
#   Created wheel for community: filename=community-1.0.0b1-py3-none-any.whl size=2152 sha256=6121e9406c5394b0c496567f5c32f2dee236380c148c57fea8f575bd36df387d
#   Stored in directory: /root/.cache/pip/wheels/d9/cf/a6/01e9b603fca646a52b27e42d5c5613cb167c5258109d59ea23
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.15-py3-none-any.whl size=9401 sha256=8730b9061af6a984e01c3cfb22de3722ec47adac4fed01c8d5deb4d1601e58c7
#   Stored in directory: /root/.cache/pip/wheels/c7/4c/ef/427db8777620f7fa12a6404f1527a39536a812f46a4d1044d3
# Successfully built fa2 community python-louvain
# Installing collected packages: networkx, fa2, texttable, igraph, wordcloud, powerlaw, itsdangerous, Flask, community, vaderSentiment, python-louvain
# Successfully installed Flask-2.0.2 community-1.0.0b1 fa2-0.3.5 igraph-0.9.8 itsdangerous-2.0.1 networkx-2.6.3 powerlaw-1.5 python-louvain-0.15 texttable-1.6.4 vaderSentiment-3.3.2 wordcloud-1.8.1
# WARNING: You are using pip version 20.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8f6f5ff7-c522-4b00-830d-73030439484f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
